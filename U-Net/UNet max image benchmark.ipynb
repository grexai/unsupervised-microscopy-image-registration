# %% [markdown]
# # Unet max number benchmark

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=0 python3 train.py config_HeLa.json HeLa_{imageset}_s{seed} --epoch=1000 --max_images={imageset}
# Out:
# wandb: Currently logged in as: grexai. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /storage01/grexai/dev/Unet-torch/wandb/run-20231103_134031-6mket6a1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run wandering-microwave-142
# wandb: ⭐️ View project at https://wandb.ai/grexai/unet%20image%20translation
# wandb: 🚀 View run at https://wandb.ai/grexai/unet%20image%20translation/runs/6mket6a1
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 1000
# NVIDIA TITAN Xp
# start training unet for 1000
# number of trainable paramter 124374339
# creating a new model
# ...
# 100%|████████████| 4/4 [00:01<00:00,  2.35it/s, epoch=199, loss=13.4, lr=0.0005]
# => Saving checkpoint
# ...

# %%
# !CUDA_VISIBLE_DEVICES=2 python3 train.py config_HeLa.json HeLa_maxdata8 --epoch=1000
# Out:
# wandb: Currently logged in as: grexai. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /storage01/grexai/dev/Unet-torch/wandb/run-20231108_141759-yio9ps1x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lunar-snowflake-209
# wandb: ⭐️ View project at https://wandb.ai/grexai/unet%20image%20translation
# wandb: 🚀 View run at https://wandb.ai/grexai/unet%20image%20translation/runs/yio9ps1x
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 1000
# NVIDIA TITAN Xp
# start training unet for 1000
# number of trainable paramter 124374339
# creating a new model
# ...
# 100%|██████████| 12/12 [00:04<00:00,  2.81it/s, epoch=199, loss=11.5, lr=0.0005]
# => Saving checkpoint
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1 python3 test.py config_HeLa.json HeLa_maxdata7 ""
# Out:
# HeLa_maxdata7
# => Loading checkpoint
# ./test_HeLa_maxdata7
# something
#   0%|                                                    | 0/69 [00:00<?, ?it/s]0.028360843658447266
# 1
#   1%|▋                                           | 1/69 [00:00<00:26,  2.59it/s]0.004633903503417969
# 1
#   3%|█▎                                          | 2/69 [00:00<00:17,  3.81it/s]0.004289865493774414
# 1
#   4%|█▉                                          | 3/69 [00:00<00:14,  4.54it/s]0.004221439361572266
# 1
#   6%|██▌                                         | 4/69 [00:00<00:13,  4.82it/s]0.004256248474121094
# 1
#   7%|███▏                                        | 5/69 [00:01<00:12,  5.10it/s]0.004370927810668945
# 1
#   9%|███▊                                        | 6/69 [00:01<00:11,  5.59it/s]0.0042078495025634766
# 1
#  10%|████▍                                       | 7/69 [00:01<00:10,  5.74it/s]0.004205465316772461
# 1
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=0 python3 train.py config_Hella.json renal_{imageset}_s{seed} --epoch=1000 --max_images={imageset}
# Out:
# wandb: Currently logged in as: grexai. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /storage01/grexai/dev/Unet-torch/wandb/run-20231108_094811-36osucv8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run brisk-salad-206
# wandb: ⭐️ View project at https://wandb.ai/grexai/unet%20image%20translation
# wandb: 🚀 View run at https://wandb.ai/grexai/unet%20image%20translation/runs/36osucv8
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 1000
# NVIDIA TITAN Xp
# start training unet for 1000
# number of trainable paramter 124374339
# creating a new model
# ...
# 100%|████████████| 4/4 [00:01<00:00,  2.23it/s, epoch=199, loss=38.6, lr=0.0001]
# => Saving checkpoint
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=0 python3 train.py config_dstrom.json dstorm_{imageset}_s{seed} --epoch=1000 --max_images={imageset}
# Out:
# wandb: Currently logged in as: grexai. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in /storage01/grexai/dev/Unet-torch/wandb/run-20231105_142304-1v05vsyc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run swept-pond-181
# wandb: ⭐️ View project at https://wandb.ai/grexai/unet%20image%20translation
# wandb: 🚀 View run at https://wandb.ai/grexai/unet%20image%20translation/runs/1v05vsyc
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 1000
# NVIDIA TITAN Xp
# start training unet for 1000
# number of trainable paramter 124374339
# creating a new model
# ...
# 100%|████████████| 4/4 [00:01<00:00,  2.44it/s, epoch=199, loss=2.12, lr=0.0001]
# => Saving checkpoint
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=2 python3 test.py config_HeLa.json HeLa_{imageset}_s{seed}
# Out:
# HeLa_25_s0
# => Loading checkpoint
# ./test_HeLa_25_s0
# something
#   0%|                                                    | 0/69 [00:00<?, ?it/s]0.015116691589355469
# 1
#   1%|▋                                           | 1/69 [00:00<00:25,  2.66it/s]0.004660844802856445
# 1
#   3%|█▎                                          | 2/69 [00:00<00:16,  4.16it/s]0.00426793098449707
# 1
#   4%|█▉                                          | 3/69 [00:00<00:14,  4.52it/s]0.004235982894897461
# 1
#   6%|██▌                                         | 4/69 [00:00<00:12,  5.13it/s]0.004309892654418945
# 1
#   7%|███▏                                        | 5/69 [00:01<00:11,  5.57it/s]0.004235982894897461
# 1
#   9%|███▊                                        | 6/69 [00:01<00:11,  5.64it/s]0.004246950149536133
# 1
#  10%|████▍                                       | 7/69 [00:01<00:10,  5.85it/s]0.004270315170288086
# 1
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=2 python3 test.py config_Hella.json renal_{imageset}_s{seed}
# Out:
# renal_25_s0
# => Loading checkpoint
# ./test_renal_25_s0
# something
#   0%|                                                    | 0/23 [00:00<?, ?it/s]0.014740943908691406
# 1
#   4%|█▉                                          | 1/23 [00:00<00:06,  3.22it/s]0.004747152328491211
# 1
# 0.004671812057495117
# 1
#  13%|█████▋                                      | 3/23 [00:00<00:02,  6.82it/s]0.004647254943847656
# 1
# 0.0043811798095703125
# 1
#  22%|█████████▌                                  | 5/23 [00:00<00:02,  8.87it/s]0.0056078433990478516
# 1
# 0.004416942596435547
# 1
#  30%|█████████████▍                              | 7/23 [00:00<00:01, 10.38it/s]0.00440216064453125
# 1
# 0.004391908645629883
# 1
#  39%|█████████████████▏                          | 9/23 [00:01<00:01, 10.17it/s]0.005352020263671875
# 1
# 0.004350185394287109
# 1
#  48%|████████████████████▌                      | 11/23 [00:01<00:01, 10.93it/s]0.0050811767578125
# 1
# 0.004355669021606445
# 1
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !CUDA_VISIBLE_DEVICES=2 python3 test.py config_dstrom.json dstorm_{imageset}_s{seed}
# Out:
# dstorm_25_s0
# => Loading checkpoint
# ./test_dstorm_25_s0
# something
#   0%|                                                    | 0/24 [00:00<?, ?it/s]0.01614975929260254
# 1
#   4%|█▊                                          | 1/24 [00:00<00:04,  4.81it/s]0.004133939743041992
# 1
# 0.005837202072143555
# 1
# 0.00411224365234375
# 1
# 0.0068552494049072266
# 1
#  21%|█████████▏                                  | 5/24 [00:00<00:01, 18.29it/s]0.004118680953979492
# 1
# 0.007355690002441406
# 1
# 0.0040781497955322266
# 1
# 0.005381345748901367
# 1
#  38%|████████████████▌                           | 9/24 [00:00<00:00, 24.14it/s]0.004126310348510742
# 1
# 0.005323171615600586
# 1
# 0.004105091094970703
# 1
# 0.005326032638549805
# 1
#  54%|███████████████████████▎                   | 13/24 [00:00<00:00, 27.45it/s]0.004117488861083984
# 1
# 0.006258487701416016
# 1
# 0.0041048526763916016
# 1
# 0.005959749221801758
# 1
# ...

# %%
# TEST bench mark with different overlaps

# %%
testsets = ['dp_10','dp_20','dp_30','dp_40','dp_50','dp_60','dp_70','dp_80','dp100','dp_200','dp_300','dp_374']
model =  'cut_b18z40_63x_unaligned_resize_selected'
for test in testsets:
    # !CUDA_VISIBLE_DEVICES=2 python3 test.py config_HeLa.json HeLa_maxdata3

# %%
CUDA_VISIBLE_DEVICES=2 python3 test.py config_HeLa.json 
CUDA_VISIBLE_DEVICES=2 python3 test.py config_Hella.json 
CUDA_VISIBLE_DEVICES=2 python3 test.py config_IHC.json 
CUDA_VISIBLE_DEVICES=2 python3 test.py config_dstrom.json

# %%
CUDA_VISIBLE_DEVICES=0 python3 train.py config_HeLa.json HeLa_L1_256_L1 --epoch=1000

# %%
CUDA_VISIBLE_DEVICES=0 python3 train.py config_HeLa.json HeLa_L1_256_L1 --epoch=1000
