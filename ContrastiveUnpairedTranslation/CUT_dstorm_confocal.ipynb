# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !python train.py --dataroot /storage01/grexai/datasets/imgreg/Image_registration/dstrom/splitted2/train/Unaligned/ \
        --name cut_dstorm_unaligned_resize_{imageset}_s{seed} --lr=0.0001 --lr_decay_iters=40 --lr_policy step --batch_size=1 --n_epochs=400 \
        --preprocess resize --load_size=256 --save_epoch_freq=60 --n_epochs=200  --display_port=8089 --gpu_ids=2 \
        --max_dataset_size {imageset}
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/imgreg/Image_registration/dstrom/splitted2/train/Unaligned/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8089                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#               epoch_count: 1
#           evaluation_freq: 5000
#         flip_equivariance: False
# ...

# %%
imagesets = [25,50,75]
seeds = [0,1,2,3,4]
for seed in seeds:
    for imageset in imagesets:
        # !python test.py --dataroot /storage01/grexai/datasets/imgreg/Image_registration/dstrom/splitted2/test \
        --preprocess resize --load_size=256 --name cut_dstorm_unaligned_resize_{imageset}_s{seed} --CUT_mode CUT --phase test --num_test=99999
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/imgreg/Image_registration/dstrom/splitted2/test	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#                      eval: False
#         flip_equivariance: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                lambda_GAN: 1.0
#                lambda_NCE: 1.0
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cut
#                n_layers_D: 3
# ...

# %% [markdown]
# # TRAIN dstorm confocal dataset
# aligend training 60-63x
# unaligend testing

# %%
# !python train.py --dataroot /storage01/grexai/datasets/Image_registration/dstrom/splitted2/test/ \
--name cut_dstorm_aligned_resize_selected  --lr=0.0001 --lr_decay_iters=40 --lr_policy step --batch_size=1 \
--preprocess resize --load_size=256 --save_epoch_freq=60 --n_epochs=150  --display_port=8087 --use_wandb
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/Image_registration/dstrom/splitted2/train/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8087                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#               epoch_count: 1
#           evaluation_freq: 5000
#         flip_equivariance: False
#                  gan_mode: lsgan
# ...

# %%
# !python test.py --dataroot /storage01/grexai/datasets/Image_registration/dstrom/splitted2/test/ \
--preprocess resize --load_size=256 --name cut_dstorm_aligned_resize_selected --CUT_mode CUT --phase train --num_test=99999
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/Image_registration/dstrom/splitted2/test/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#                      eval: False
#         flip_equivariance: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                lambda_GAN: 1.0
#                lambda_NCE: 1.0
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cut
#                n_layers_D: 3
# ...

# %%
# !python train.py --dataroot /storage01/grexai/datasets/Image_registration/dstrom/splitted2/train/ \
--name cut_dstorm_aligned_resize_selected_ba --dir BtoA  --lr=0.0001 --lr_decay_iters=40 --lr_policy step --batch_size=1 \
--preprocess resize --load_size=256 --save_epoch_freq=60 --n_epochs=150  --display_port=8087
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/Image_registration/dstrom/splitted2/train/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: BtoA                          	[default: AtoB]
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8087                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#               epoch_count: 1
#           evaluation_freq: 5000
#         flip_equivariance: False
# ...

# %%
# unaligned training

# %%
# !python train.py --dataroot /storage01/grexai/datasets/Image_registration/dstrom/splitted2/train/Unaligned/ \
--name cut_dstorm_unaligned_resize_selected  --lr=0.0001 --lr_decay_iters=40 --lr_policy step --batch_size=1 \
--preprocess resize --load_size=256 --save_epoch_freq=60 --n_epochs=150  --display_port=8087 --use_wandb
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/Image_registration/dstrom/splitted2/train/Unaligned/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8087                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#               epoch_count: 1
#           evaluation_freq: 5000
#         flip_equivariance: False
#                  gan_mode: lsgan
# ...

# %%
#test unaligned

# %%
# !python test.py --dataroot /storage01/grexai/datasets/Image_registration/dstrom/splitted2/test/ \
--preprocess resize --load_size=256 --name cut_dstorm_unaligned_resize_selected --CUT_mode CUT --phase train --num_test=99999
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /storage01/grexai/datasets/Image_registration/dstrom/splitted2/test/	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#                      eval: False
#         flip_equivariance: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                lambda_GAN: 1.0
#                lambda_NCE: 1.0
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cut
#                n_layers_D: 3
# ...

# %%
#test on image resize ALGINED
